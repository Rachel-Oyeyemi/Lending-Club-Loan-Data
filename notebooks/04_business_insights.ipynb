# %% [markdown]
# # 04 – Business Insights
#
# Summarise the modelling results and translate them into business recommendations.

# %% [markdown]
# After evaluating multiple models, the Random Forest and gradient-boosting models achieved the best performance.
#
# Key drivers of default include high debt-to-income ratios, high interest rates, lower credit grades, and large loan amounts relative to annual income.  See `BUSINESS_RECOMMENDATIONS.md` for a detailed discussion of these insights.
