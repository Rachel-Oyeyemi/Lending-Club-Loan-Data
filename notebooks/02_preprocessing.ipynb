# %% [markdown]
# # 02 – Preprocessing
#
# This notebook demonstrates how to preprocess the raw Lending Club dataset.

# %%
from src.preprocess import preprocess

# Example usage:
# preprocess(path='../data/raw/accepted_2007_to_2018Q4.csv',
#           output_path='../data/processed/lending_club_processed.csv',
#           missing_threshold=0.4)

# %% [markdown]
# The preprocessing script drops columns with a high proportion of missing values, converts string fields to numeric, encodes categorical variables and maps the target variable to a binary flag.
