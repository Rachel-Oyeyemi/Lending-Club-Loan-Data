# %% [markdown]
# # 03 – Modeling
#
# Train baseline and advanced models on the engineered dataset.

# %%
from src.train_model import train_models
import pandas as pd

# Load engineered data
df = pd.read_csv('../data/processed/lending_club_engineered.csv')

# Train models and save them to '../models'
train_models(df, '../models')

# %% [markdown]
# The models trained include logistic regression, random forest and gradient boosting implementations.
